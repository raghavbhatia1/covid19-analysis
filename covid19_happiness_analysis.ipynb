# %% [markdown]
# # COVID-19 and Happiness Data Analysis Project
# This project analyzes the relationship between COVID-19 confirmed cases and various happiness indicators using data from the Johns Hopkins COVID-19 time series and the Worldwide Happiness Report.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# Load datasets
covid_df = pd.read_csv('time_series_covid19_confirmed_global.csv')
happiness_df = pd.read_csv('worldwide_happiness_report.csv')

# %%
# Display the first few rows of the COVID-19 dataset
covid_df.head()

# %%
# Display the first few rows of the Happiness dataset
happiness_df.head()
